# %%
import requests
import json 
import pandas as pd

url = "https://unofficial-redfin.p.rapidapi.com/properties/list"

querystring = {"region_id":"11323","region_type":"2","uipt":"1","status":"1","num_homes":"400"}

headers = {
	"X-RapidAPI-Key": "cdb870e360mshf99c09c9ee58689p1672b1jsn9005f25d5e10",
	"X-RapidAPI-Host": "unofficial-redfin.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

data = response.json() 

#df = pd.json_normalize(data, record_path=['homes'])
#df

print(json.dumps(data, indent=4))
# Out:
# {
#     "homes": [
#         {
#             "homeData": {
#                 "propertyId": "181149250",
#                 "listingId": {
#                     "value": "156092267"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "3896588",
#                 "url": "/NC/Richfield/307-Stoneyard-RD-Unknown/home/181149250",
#                 "dataSourceId": {
#                     "value": "103"
#                 },
#                 "marketId": {
#                     "value": "19"
#                 },
#                 "businessMarketId": {
#                     "value": "21"
#                 },
#                 "mlsStatusId": {
#                     "value": "3142"
#                 },
#                 "servicePolicyId": {
#                     "value": "13"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 4
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "449000"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "449000"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2570"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "version": "4"
#                         },
#                         {
#                             "startPos": 1,
#                             "endPos": 1,
#                             "version": "3"
#                         },
#                         {
#                             "startPos": 2,
#                             "endPos": 19,
#                             "version": "2"
#                         },
#                         {
#                             "startPos": 20,
#                             "endPos": 21,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "19"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "1636374",
#                         "nanos": 752000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1660876620",
#                         "nanos": 154000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2022
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "30491"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 18,
#                         "sashTypeName": "New Construction",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {},
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 35.471684,
#                             "longitude": -80.273288
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "307 Stoneyard Rd",
#                     "city": "Richfield",
#                     "state": "NC",
#                     "zip": "28137",
#                     "location": "Richfield",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "52278005",
#                 "listingId": {
#                     "value": "153558686"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "3883494",
#                 "url": "/NC/Richfield/215-Big-Buck-Dr-28137/home/52278005",
#                 "dataSourceId": {
#                     "value": "103"
#                 },
#                 "marketId": {
#                     "value": "19"
#                 },
#                 "mlsStatusId": {
#                     "value": "3142"
#                 },
#                 "servicePolicyId": {
#                     "value": "4"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS"
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 3
#                 },
#                 "baths": {
#                     "value": 2.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "309900"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "309900"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "1558"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "version": "3"
#                         },
#                         {
#                             "startPos": 1,
#                             "endPos": 6,
#                             "version": "2"
#                         },
#                         {
#                             "startPos": 7,
#                             "endPos": 8,
#                             "version": "0"
#                         },
#                         {
#                             "startPos": 9,
#                             "endPos": 43,
#                             "version": "1"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "37"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "3191581",
#                         "nanos": 43000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1657742535",
#                         "nanos": 794000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 1966
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "121967"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "brokers": {},
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 2,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 35.5895518,
#                             "longitude": -80.2399949
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "215 Big Buck Dr",
#                     "city": "Richfield",
#                     "state": "NC",
#                     "zip": "28137",
#                     "location": "Richfield",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "179395544",
#                 "listingId": {
#                     "value": "149985288"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "3860047",
#                 "url": "/NC/Richfield/310-Stoneyard-HWY-Unknown/unit-12/home/179395544",
#                 "dataSourceId": {
#                     "value": "103"
#                 },
#                 "marketId": {
#                     "value": "19"
#                 },
#                 "businessMarketId": {
#                     "value": "21"
#                 },
#                 "mlsStatusId": {
#                     "value": "3142"
#                 },
#                 "servicePolicyId": {
#                     "value": "13"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 3
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "389500"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "389500"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "1973"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 9,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "119"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "10285358",
#                         "nanos": 576000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1652319460",
#                         "nanos": 893000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2022
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "35806"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 18,
#                         "sashTypeName": "New Construction",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {},
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 35.47164,
#                             "longitude": -80.272073
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "310 Stoneyard Hwy #12",
#                     "city": "Richfield",
#                     "state": "NC",
#                     "zip": "28137",
#                     "location": "Richfield",
#                     "unitNumber": "#12",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         }
#     ]
# }
