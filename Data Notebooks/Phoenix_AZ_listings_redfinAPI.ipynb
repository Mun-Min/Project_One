# %%
import requests
import json 
import pandas as pd

region_id = 14240

url = "https://unofficial-redfin.p.rapidapi.com/properties/list?region_id=14240&region_type=2&uipt=1&status=1&num_homes=300"
beds = []
baths = []
print(f"Start API acquisition")

# for i in 
# querystring = {"region_id":"14240","region_type":"2","uipt":"1","status":"1","num_homes":"300"}

headers = {
	"X-RapidAPI-Key": "cdb870e360mshf99c09c9ee58689p1672b1jsn9005f25d5e10",
	"X-RapidAPI-Host": "unofficial-redfin.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

data = response.json() 
# df = pd.DataFrame.from_dict(data['homes'][0])
# df
# beds= data['homes'][0]['homeData']['beds']['value']
#df = pd.DataFrame.from_dict(data, orient = 'index')

#df = pd.json_normalize(data, record_path=['homes'])
#df
dict= {"BEDS":beds}
print(json.dumps(data, indent=4))
# Out:
# {
#     "homes": [
#         {
#             "homeData": {
#                 "propertyId": "48415622",
#                 "listingId": {
#                     "value": "156727021"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3400036",
#                 "url": "/FL/Lutz/1135-Wisper-Run-Ct-33558/home/48415622",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "isRedfin": true,
#                     "hasVirtualTour": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 3
#                 },
#                 "baths": {
#                     "value": 3.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "684900"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "684900"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2638"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 48,
#                             "version": "0"
#                         }
#                     ],
#                     "alternatePhotosInfo": [
#                         {
#                             "mediaListType": "1",
#                             "groupCode": "749689_JPG",
#                             "positionSpec": [
#                                 81,
#                                 83,
#                                 84,
#                                 85,
#                                 86,
#                                 87,
#                                 88,
#                                 89,
#                                 90,
#                                 91,
#                                 92,
#                                 93,
#                                 94,
#                                 95,
#                                 96,
#                                 97,
#                                 108,
#                                 109,
#                                 110,
#                                 111,
#                                 112,
#                                 113,
#                                 114,
#                                 98,
#                                 99,
#                                 102,
#                                 103,
#                                 100,
#                                 101,
#                                 104,
#                                 105,
#                                 107,
#                                 115,
#                                 116,
#                                 117,
#                                 118,
#                                 119,
#                                 120,
#                                 121,
#                                 122,
#                                 123,
#                                 124,
#                                 125,
#                                 126,
#                                 127,
#                                 128,
#                                 129
#                             ],
#                             "photoType": "DEAL"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "scanUrl": "https://my.matterport.com/show/?m=GFQJQS8e8BA&mls=1",
#                     "posterFrameUrl": "https://my.matterport.com/api/v2/player/models/GFQJQS8e8BA/thumb"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "1"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "52270",
#                         "nanos": 185000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1662558129",
#                         "nanos": 863000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 1983
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "26850"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "isRedfin": true,
#                         "sashTypeId": 7,
#                         "sashTypeName": "New",
#                         "sashTypeColor": "#2E7E36",
#                         "timeOnRedfin": "52270185"
#                     },
#                     {
#                         "sashTypeId": 31,
#                         "sashTypeName": "3D Walkthrough",
#                         "sashTypeColor": "#7556F2"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "redfinAgentId": {
#                             "value": "17589"
#                         },
#                         "agentName": "Jonathan Benn"
#                     }
#                 },
#                 "lastSaleData": {
#                     "lastSoldDate": {
#                         "seconds": "1633503600"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 3
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 3,
#                     "computedFullBaths": 3,
#                     "computedTotalBaths": 3.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1741213,
#                             "longitude": -82.4791503
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "1135 Wisper Run Ct",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "WISPER RUN",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "47099534",
#                 "listingId": {
#                     "value": "156726904"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3400912",
#                 "url": "/FL/Lutz/4613-Corsage-Dr-33558/home/47099534",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS"
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 3
#                 },
#                 "baths": {
#                     "value": 2.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "450000"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "450000"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "1921"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 29,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "1"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "52618",
#                         "nanos": 322000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1662557781",
#                         "nanos": 726000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 1999
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "5252"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "111"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 24,
#                         "sashTypeName": "Price Drop",
#                         "sashTypeColor": "#2E7E36"
#                     },
#                     {
#                         "sashTypeId": 7,
#                         "sashTypeName": "New",
#                         "sashTypeColor": "#2E7E36",
#                         "timeOnRedfin": "52618322"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Kaleze Mendez"
#                     }
#                 },
#                 "lastSaleData": {
#                     "lastSoldDate": {
#                         "seconds": "1333090800"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 2,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1621071,
#                             "longitude": -82.5183723
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "4613 Corsage Dr",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "VILLAROSA PH F",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "47388239",
#                 "listingId": {
#                     "value": "156658461"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3397413",
#                 "url": "/FL/Lutz/5016-Bridgeway-Ln-33558/home/47388239",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS"
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 4
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "420000"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "420000"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "1922"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 25,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "4"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "385716",
#                         "nanos": 546000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1662224683",
#                         "nanos": 502000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2002
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "4050"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "291"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Christine Delgado"
#                     }
#                 },
#                 "lastSaleData": {
#                     "lastSoldDate": {
#                         "seconds": "1265788800"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1303596,
#                             "longitude": -82.5216661
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "5016 Bridgeway Ln",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "REFLECTIONS PH 1",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "47103108",
#                 "listingId": {
#                     "value": "156615116"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "U8174663",
#                 "url": "/FL/Lutz/4329-Hawks-Nest-Dr-33558/home/47103108",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "hasVirtualTour": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 4
#                 },
#                 "baths": {
#                     "value": 3.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "540000"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "540000"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2581"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 37,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "6"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "525131",
#                         "nanos": 252000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1662085268",
#                         "nanos": 796000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 1996
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "11956"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "56"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "openHouseText": "OPEN SAT TO 3PM",
#                         "sashTypeId": 10,
#                         "sashTypeName": "Open House",
#                         "sashTypeColor": "#73BB3C"
#                     },
#                     {
#                         "sashTypeId": 31,
#                         "sashTypeName": "3D Walkthrough",
#                         "sashTypeColor": "#7556F2"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Kim Nestor"
#                     }
#                 },
#                 "openHouses": [
#                     {
#                         "openHouseStart": {
#                             "seconds": "1662782400"
#                         },
#                         "openHouseEnd": {
#                             "seconds": "1662836400"
#                         }
#                     }
#                 ],
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 3
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 3,
#                     "computedFullBaths": 3,
#                     "computedTotalBaths": 3.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1325351,
#                             "longitude": -82.5131506
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "4329 Hawks Nest Dr",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "CALUSA TRACE TRACT 12",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "46976668",
#                 "listingId": {
#                     "value": "156579073"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3399943",
#                 "url": "/FL/Lutz/18917-Fishermans-Bend-Dr-33558/home/46976668",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "hasVirtualTour": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 4
#                 },
#                 "baths": {
#                     "value": 3.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "499900"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "499900"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2008"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 43,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "7"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "615769",
#                         "nanos": 369000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1661994630",
#                         "nanos": 679000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2004
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "5500"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "125"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 32,
#                         "sashTypeName": "Video Tour",
#                         "sashTypeColor": "#7556F2"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Neill Boyd"
#                     }
#                 },
#                 "lastSaleData": {
#                     "lastSoldDate": {
#                         "seconds": "1596610800"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 3
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 3,
#                     "computedFullBaths": 3,
#                     "computedTotalBaths": 3.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1575384,
#                             "longitude": -82.5008874
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "18917 Fishermans Bend Dr",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "HERITAGE HARBOR VILLAGE 17",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "180547017",
#                 "listingId": {
#                     "value": "156483111"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3397961",
#                 "url": "/FL/Lutz/17947-Blissful-Stars-Dr-33558/home/180547017",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 5
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "499990"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "499990"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2389"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 12,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "8"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "742222",
#                         "nanos": 356000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1661868177",
#                         "nanos": 692000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2022
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "48"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 24,
#                         "sashTypeName": "Price Drop",
#                         "sashTypeColor": "#2E7E36"
#                     },
#                     {
#                         "sashTypeId": 18,
#                         "sashTypeName": "New Construction",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Ben Goldstein"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1872315,
#                             "longitude": -82.5194677
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "17947 Blissful Stars Dr",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "CYPRESS RANCH",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "181253512",
#                 "listingId": {
#                     "value": "156483101"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3397959",
#                 "url": "/FL/Lutz/18010-Blissful-Stars-Dr-33558/home/181253512",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 6
#                 },
#                 "baths": {
#                     "value": 3.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "509990"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "509990"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2580"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 6,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "8"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "742223",
#                         "nanos": 173000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1661868176",
#                         "nanos": 875000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2022
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "48"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 24,
#                         "sashTypeName": "Price Drop",
#                         "sashTypeColor": "#2E7E36"
#                     },
#                     {
#                         "sashTypeId": 18,
#                         "sashTypeName": "New Construction",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Ben Goldstein"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 3
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 3,
#                     "computedFullBaths": 3,
#                     "computedTotalBaths": 3.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1867614,
#                             "longitude": -82.5184184
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "18010 Blissful Stars Dr",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "CYPRESS RANCH",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "47062500",
#                 "listingId": {
#                     "value": "156188857"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "T3397121",
#                 "url": "/FL/Lutz/3120-Majestic-View-Dr-33558/home/47062500",
#                 "dataSourceId": {
#                     "value": "118"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "3517"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "MLS"
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 4
#                 },
#                 "baths": {
#                     "value": 2.0
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "599500"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "599500"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2408"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 18,
#                             "version": "0"
#                         },
#                         {
#                             "startPos": 19,
#                             "endPos": 19,
#                             "version": "1"
#                         },
#                         {
#                             "startPos": 20,
#                             "endPos": 20,
#                             "version": "0"
#                         },
#                         {
#                             "startPos": 21,
#                             "endPos": 21,
#                             "version": "1"
#                         },
#                         {
#                             "startPos": 22,
#                             "endPos": 43,
#                             "version": "0"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "daysOnMarket": {
#                         "value": "16"
#                     },
#                     "timeOnRedfin": {
#                         "seconds": "1411484",
#                         "nanos": 960000000
#                     },
#                     "listingAddedDate": {
#                         "seconds": "1661198915",
#                         "nanos": 88000000
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "yearBuilt": {
#                         "value": 2012
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "amount": {
#                         "value": "7800"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "amount": {
#                         "value": "95"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 24,
#                         "sashTypeName": "Price Drop",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {
#                     "listingBrokerAndAgent": {
#                         "agentName": "Lauren Borio"
#                     }
#                 },
#                 "lastSaleData": {
#                     "lastSoldDate": {
#                         "seconds": "1383897600"
#                     }
#                 },
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "bathInfo": {
#                     "rawFullBaths": 2,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.0
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1635374,
#                             "longitude": -82.4917943
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "3120 Majestic View Dr",
#                     "city": "LUTZ",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "STONEBRIER",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
# ...
#                     "value": "151145629"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "Plan-201961896",
#                 "url": "/FL/Lutz/Cypress-Ranch-The-Manors/Boston/home/178472133",
#                 "dataSourceId": {
#                     "value": "113"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "497"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "NEW_CONSTRUCTION_PLAN",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 5
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "501990"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "501990"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2215"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 1,
#                             "version": "0"
#                         },
#                         {
#                             "startPos": 6,
#                             "endPos": 6,
#                             "version": "4"
#                         },
#                         {
#                             "startPos": 7,
#                             "endPos": 8,
#                             "version": "5"
#                         },
#                         {
#                             "startPos": 9,
#                             "endPos": 12,
#                             "version": "4"
#                         },
#                         {
#                             "startPos": 13,
#                             "endPos": 26,
#                             "version": "3"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "listingAddedDate": {
#                         "seconds": "1654214618",
#                         "nanos": 248000000
#                     },
#                     "displayLevel": "CENSORED"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 17,
#                         "sashTypeName": "Ready to Build",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {},
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1296785,
#                             "longitude": -82.5096231
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "Boston",
#                     "city": "Lutz",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "Cypress Ranch - The Manors",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "178472132",
#                 "listingId": {
#                     "value": "151145628"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "Plan-201961897",
#                 "url": "/FL/Lutz/Cypress-Ranch-The-Manors/Columbia/home/178472132",
#                 "dataSourceId": {
#                     "value": "113"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "497"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "NEW_CONSTRUCTION_PLAN",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 5
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "523990"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "523990"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "2389"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 1,
#                             "version": "0"
#                         },
#                         {
#                             "startPos": 6,
#                             "endPos": 17,
#                             "version": "3"
#                         },
#                         {
#                             "startPos": 18,
#                             "endPos": 21,
#                             "version": "2"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "listingAddedDate": {
#                         "seconds": "1654214618",
#                         "nanos": 96000000
#                     },
#                     "displayLevel": "CENSORED"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 17,
#                         "sashTypeName": "Ready to Build",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {},
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1296785,
#                             "longitude": -82.5096231
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "Columbia",
#                     "city": "Lutz",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "Cypress Ranch - The Manors",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         },
#         {
#             "homeData": {
#                 "propertyId": "178472134",
#                 "listingId": {
#                     "value": "151008373"
#                 },
#                 "listingDisplayLevel": "ACCESSIBLE",
#                 "mlsId": "Plan-201961895",
#                 "url": "/FL/Lutz/Cypress-Ranch-The-Manors/Atlanta/home/178472134",
#                 "dataSourceId": {
#                     "value": "113"
#                 },
#                 "marketId": {
#                     "value": "28"
#                 },
#                 "businessMarketId": {
#                     "value": "86"
#                 },
#                 "mlsStatusId": {
#                     "value": "497"
#                 },
#                 "servicePolicyId": {
#                     "value": "14"
#                 },
#                 "listingMetadata": {
#                     "searchStatus": "ACTIVE",
#                     "listingType": "NEW_CONSTRUCTION_PLAN",
#                     "isNewConstruction": true
#                 },
#                 "propertyType": "SINGLE_FAMILY_RESIDENTIAL",
#                 "beds": {
#                     "value": 4
#                 },
#                 "baths": {
#                     "value": 2.5
#                 },
#                 "priceInfo": {
#                     "amount": {
#                         "value": "478490"
#                     },
#                     "displayLevel": "ACCESSIBLE",
#                     "priceType": "LISTING_PRICE",
#                     "homePrice": {
#                         "displayLevel": "ACCESSIBLE",
#                         "int64Value": "478490"
#                     }
#                 },
#                 "sqftInfo": {
#                     "amount": {
#                         "value": "1870"
#                     },
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "photosInfo": {
#                     "photoRanges": [
#                         {
#                             "endPos": 1,
#                             "version": "1"
#                         },
#                         {
#                             "startPos": 6,
#                             "endPos": 8,
#                             "version": "2"
#                         },
#                         {
#                             "startPos": 9,
#                             "endPos": 12,
#                             "version": "1"
#                         }
#                     ],
#                     "primaryPhotoDisplayLevel": "ACCESSIBLE",
#                     "secondaryPhotoDisplayLevel": "ACCESSIBLE"
#                 },
#                 "daysOnMarket": {
#                     "listingAddedDate": {
#                         "seconds": "1654041977",
#                         "nanos": 176000000
#                     },
#                     "displayLevel": "CENSORED"
#                 },
#                 "timezone": "US/Eastern",
#                 "yearBuilt": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "lotSize": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "hoaDues": {
#                     "displayLevel": "ACCESSIBLE"
#                 },
#                 "sashes": [
#                     {
#                         "sashTypeId": 17,
#                         "sashTypeName": "Ready to Build",
#                         "sashTypeColor": "#2E7E36"
#                     }
#                 ],
#                 "brokers": {},
#                 "personalization": {},
#                 "insights": {},
#                 "showMlsId": {},
#                 "directAccessInfo": {
#                     "supportPhoneNumber": "N/A",
#                     "timeZone": {
#                         "id": 7,
#                         "timeZoneIdString": "US/Pacific",
#                         "olsonTimeZoneIdString": "America/Los_Angeles",
#                         "description": "Pacific Time in the United States"
#                     }
#                 },
#                 "fullBaths": {
#                     "value": 2
#                 },
#                 "partialBaths": {
#                     "value": 1
#                 },
#                 "bathInfo": {
#                     "rawHalfBaths": 1,
#                     "rawFullBaths": 2,
#                     "computedPartialBaths": 1,
#                     "computedFullBaths": 2,
#                     "computedTotalBaths": 2.5
#                 },
#                 "addressInfo": {
#                     "centroid": {
#                         "centroid": {
#                             "latitude": 28.1296785,
#                             "longitude": -82.5096231
#                         },
#                         "displayLevel": "ACCESSIBLE"
#                     },
#                     "formattedStreetLine": "Atlanta",
#                     "city": "Lutz",
#                     "state": "FL",
#                     "zip": "33558",
#                     "location": "Cypress Ranch - The Manors",
#                     "streetlineDisplayLevel": "ACCESSIBLE",
#                     "unitNumberDisplayLevel": "ACCESSIBLE",
#                     "locationDisplayLevel": "ACCESSIBLE",
#                     "countryCode": "UNITED_STATES",
#                     "postalCodeDisplayLevel": "ACCESSIBLE"
#                 }
#             },
#             "defaultExtension": {}
#         }
#     ]
# }
